# %% [markdown]
# # Задание 1
# Создайте пустой список list1. Добавьте в него последовательно числа 1, 2, 3 с помощью метода .append(). Выведите результат. В качестве ответа запишите результат вывода.

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 2
# 1. Создайте список list2, используя метод range().
# 2. В качестве левой границы списка установите число -5 (минус пять), в качестве правой — число 15.
# 3. Задайте шаг, равный 2.
# 4. Создайте переменную list3, в которой будут числа 1,2,3,4.
# 5. Используя метод .extend() у списка list3, добавьте list2.
# Выведите список list3.

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 3
# 1. Создайте список list6. В этом списке должны быть цифры в следующем порядке: 3, 1, -10, 5, 11, 20, 1, -10.
# 2. Скопируйте содержимое списка в переменную list7.
# 3. Произведите сортировку списка list6, а затем инвертируйте полученный список.
# 4. Сохраните результат в переменную list_result.
# Выведите списки в переменных list7 и list_result.

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 4
# 1. Создайте список list1. Положите в него два значения: 10, 15.
# 2. Преобразуйте список в кортеж и сохраните результат в tpl1.
# 3. Создайте словарь dict1.
# 4. По ключу, который соответствует кортежу tpl1, положите значение 'hello'.
# Выведите полученный словарь dict1.

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 5
# Создайте два множества: s1 и s2, положив в первое множество значения из строки 'hello', а во второе множество - значения из списка ['w', 'o', 'w']. Выведите результаты объединения, пересечения, вычитания этих двух множеств.
# В качестве ответа запишите результат вывода (обязательно соблюдайте порядок вывода). Результат вывода нужно записать в одну строку через один пробел.

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 6
# Создайте два словаря: dict1 и dict2. Положите в первый словарь по ключу 'name' значение 'unknown', а во второй по ключу 'name' положите значение 'Tom'.
# 1. Выведите dict1 и dict2.
# 2. Выведите ключи и значения из dict1. Для этого используйте методы dict.keys() и dict.values().

# %%
# запишите решение здесь

# %% [markdown]
# # Задание 7
# Выведите переменную result, которая является сложением строки 'age is ' (в конце строки есть пробел) и числа 15. Воспользуйтесь преобразованием типов. В качестве ответа запишите результат вывода.

# %%
# запишите решение здесь
